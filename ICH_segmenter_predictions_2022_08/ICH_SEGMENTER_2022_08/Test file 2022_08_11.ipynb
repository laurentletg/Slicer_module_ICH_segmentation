# %%
from genericpath import exists
import os
from ssl import _create_unverified_context
import unittest
import logging
import vtk, qt, ctk, slicer
from slicer.ScriptedLoadableModule import *
from slicer.util import VTKObservationMixin
from slicer.util import getNode
from glob import glob
import re
import time
import pandas as pd
# Out:
# ------------------------------
# Reloading module: ICH_SEGMENTER_2022_08
# ------------------------------
#
#
#
#
#
#
# ------------------------------
# Reloading module: ICH_SEGMENTER_2022_08
# ------------------------------
#
#
#
# Clicked Browse Button
# Current path /Users/laurentletourneau-guillon/Dropbox (Personal)/CHUM/RECHERCHE/2020ICHHEMATOMAS/2022 Marie-Jeanne/2022_08_09 GUI to load predictions/DATA/Volumes
# Current Folder
# /Users/laurentletourneau-guillon/Dropbox (Personal)/CHUM/RECHERCHE/2020ICHHEMATOMAS/2022 Marie-Jeanne/2022_08_09 GUI to load predictions/DATA/Volumes
# FDASFASDFSAFSAFASFAS/Users/laurentletourneau-guillon/Dropbox (Personal)/CHUM/RECHERCHE/2020ICHHEMATOMAS/2022 Marie-Jeanne/2022_08_09 GUI to load predictions/DATA/Volumes/*.nrrd
# Case paths::::
# ...

# %%
# slicer.util.loadSegmentation(currentCasePath)
segmentEditorWidget = slicer.modules.segmenteditor.widgetRepresentation().self().editor
segmentEditorNode =  segmentEditorWidget.mrmlSegmentEditorNode()
segmentationNode= slicer.util.getNodesByClass('vtkMRMLSegmentationNode')[0]
nn = segmentationNode.GetDisplayNode()
# set Segmentation visible:
nn.SetAllSegmentsVisibility(True)
# segmentationNode.
# Out:
# PushButton_1 pressed
# Traceback (most recent call last):
#   File "/Users/laurentletourneau-guillon/Dropbox (Personal)/CHUM/RECHERCHE/2020ICHHEMATOMAS/2022 Marie-Jeanne/2022_08_09 GUI to load predictions/SLICER_MODULE/ICH_segmenter_predictions_2022_08/ICH_SEGMENTER_2022_08/ICH_SEGMENTER_2022_08.py", line 511, in onPushButton_1
#     self.effect.activate()
# AttributeError: 'NoneType' object has no attribute 'activate'
#
# If you suspect this is an IPython 8.2.0 bug, please report it at:
#     https://github.com/ipython/ipython/issues
# or send an email to the mailing list at ipython-dev@python.org
#
# You can print a more detailed traceback right now with "%tb", or use "%debug"
# to interactively debug it.
#
# Extra-detailed tracebacks for bug-reporting purposes can be enabled via:
#     %config Application.verbose_crash=True
# ------------------------------
# Reloading module: ICH_SEGMENTER_2022_08
# ------------------------------
#
#
#
# Clicked Browse Button
# ...

# %%
segmentationNode.GetName()
# Out:
# 'ID_42b5c14d_ICH_pred'
# Clicked Browse Button
# Current path /Users/laurentletourneau-guillon/Dropbox (Personal)/CHUM/RECHERCHE/2020ICHHEMATOMAS/2022 Marie-Jeanne/2022_08_09 GUI to load predictions/DATA/Volumes
# Current Folder
#
# FDASFASDFSAFSAFASFAS/*.nrrd
# Case paths::::
# []
# Case numbers::::
# []
# Traceback (most recent call last):
#   File "/Users/laurentletourneau-guillon/Dropbox (Personal)/CHUM/RECHERCHE/2020ICHHEMATOMAS/2022 Marie-Jeanne/2022_08_09 GUI to load predictions/SLICER_MODULE/ICH_segmenter_predictions_2022_08/ICH_SEGMENTER_2022_08/ICH_SEGMENTER_2022_08.py", line 192, in onBrowseFoldersButton
#     self.updateCaseAll()
#   File "/Users/laurentletourneau-guillon/Dropbox (Personal)/CHUM/RECHERCHE/2020ICHHEMATOMAS/2022 Marie-Jeanne/2022_08_09 GUI to load predictions/SLICER_MODULE/ICH_segmenter_predictions_2022_08/ICH_SEGMENTER_2022_08/ICH_SEGMENTER_2022_08.py", line 198, in updateCaseAll
#     self.currentCase = self.Cases[self.currentCase_index]
# ...

# %%
print('Hello')
# Out:
# Hello

# %%
test = slicer.util.getNodesByClass('vtkMRMLScalarVolumeNode')[0]

# %%
test.GetName()
# Out:
# 'Volume_ID_42b5c14d'

# %%
slicer.util.saveNode(test, os.path.join(os.getcwd(), 'test.nrrd'))
# Out:
# True
# ------------------------------
# Reloading module: ICH_SEGMENTER_2022_08
# ------------------------------
#
#
#
#
#
#
# ------------------------------
# Reloading module: ICH_SEGMENTER_2022_08
# ------------------------------
#
#
#
#
#
#
# ------------------------------
# Reloading module: ICH_SEGMENTER_2022_08
# ------------------------------
#
#
#
#
#
#
# ------------------------------
# Reloading module: ICH_SEGMENTER_2022_08
# ------------------------------
#
#
#
# Clicked Browse Button
# Current path /Users/laurentletourneau-guillon/Dropbox (Personal)/CHUM/RECHERCHE/2020ICHHEMATOMAS/2022 Marie-Jeanne/2022_08_09 GUI to load predictions/DATA/Volumes
# Current Folder
# /Users/laurentletourneau-guillon/Dropbox (Personal)/CHUM/RECHERCHE/2020ICHHEMATOMAS/2022 Marie-Jeanne/2022_08_09 GUI to load predictions/DATA/Volumes
# ...

# %%
Vol = 'Volume_ID_42b5c14d'
SlicerVolumeName = re.findall('Volume_(ID_[a-zA-Z\d]+)', Vol)[0]
print(SlicerVolumeName)
# Out:
# ID_42b5c14d
# Clicked Browse Button
# Current path /Users/laurentletourneau-guillon/Dropbox (Personal)/CHUM/RECHERCHE/2020ICHHEMATOMAS/2022 Marie-Jeanne/2022_08_09 GUI to load predictions/DATA/Volumes
# Current Folder
# /Users/laurentletourneau-guillon/Dropbox (Personal)/Mac/Downloads/MJN_To_be_annotated
# FDASFASDFSAFSAFASFAS/Users/laurentletourneau-guillon/Dropbox (Personal)/Mac/Downloads/MJN_To_be_annotated/*.nrrd
# Case paths::::
# ...
